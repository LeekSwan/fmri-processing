# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def grid_display(list_of_images, list_of_titles=[], no_of_columns=5, figsize=(25,25)):

    fig = plt.figure(figsize=figsize)
    column = 0
    for i in range(len(list_of_images)):
        column += 1
        #  check for end of column and create a new figure
        if column == no_of_columns+1:
            fig = plt.figure(figsize=figsize)
            column = 1
        fig.add_subplot(1, no_of_columns, column)
        plt.imshow(list_of_images[i])
        plt.axis('off')
        if len(list_of_titles) >= len(list_of_images):
            plt.title(list_of_titles[i])

# %%
image = [cv2.imread("Regression_pics/1-1.png"), cv2.imread("Regression_pics/1-2.png"), cv2.imread("Regression_pics/1-3.png"), cv2.imread("Regression_pics/1-4.png"), cv2.imread("Regression_pics/1-5.png"), 
         cv2.imread("Regression_pics/2-1.png"), cv2.imread("Regression_pics/2-2.png"), cv2.imread("Regression_pics/2-3.png"), cv2.imread("Regression_pics/2-4.png"), cv2.imread("Regression_pics/2-5.png"),
         cv2.imread("Regression_pics/3-1.png"), cv2.imread("Regression_pics/3-2.png"), cv2.imread("Regression_pics/3-3.png"), cv2.imread("Regression_pics/3-4.png"), cv2.imread("Regression_pics/3-5.png"),
         cv2.imread("Regression_pics/4-1.png"), cv2.imread("Regression_pics/4-2.png"), cv2.imread("Regression_pics/4-3.png"), cv2.imread("Regression_pics/4-4.png"), cv2.imread("Regression_pics/4-5.png"),
         cv2.imread("Regression_pics/5-1.png"), cv2.imread("Regression_pics/5-2.png"), cv2.imread("Regression_pics/5-3.png"), cv2.imread("Regression_pics/5-4.png"), cv2.imread("Regression_pics/5-5.png"),
         cv2.imread("Regression_pics/6-1.png"), cv2.imread("Regression_pics/6-2.png"), cv2.imread("Regression_pics/6-3.png"), cv2.imread("Regression_pics/6-4.png"), cv2.imread("Regression_pics/6-5.png"),
         cv2.imread("Regression_pics/7-1.png"), cv2.imread("Regression_pics/7-2.png"), cv2.imread("Regression_pics/7-3.png"), cv2.imread("Regression_pics/7-4.png"), cv2.imread("Regression_pics/7-5.png"),
         cv2.imread("Regression_pics/8-1.png"), cv2.imread("Regression_pics/8-2.png"), cv2.imread("Regression_pics/8-3.png"), cv2.imread("Regression_pics/8-4.png"), cv2.imread("Regression_pics/8-5.png"),
         cv2.imread("Regression_pics/9-1.png"), cv2.imread("Regression_pics/9-2.png"), cv2.imread("Regression_pics/9-3.png"), cv2.imread("Regression_pics/9-4.png"), cv2.imread("Regression_pics/9-5.png"),
         cv2.imread("Regression_pics/10-1.png"), cv2.imread("Regression_pics/10-2.png"), cv2.imread("Regression_pics/10-3.png"), cv2.imread("Regression_pics/10-4.png"), cv2.imread("Regression_pics/10-5.png")
        ]

titles = []
for i in range (1,11):
    for j in range(1,6):
        titles.append("Regression " + str(i)+"-" + str(j))
#image = []
#for i in range(1,6):
   # image.append('Regression_pics/1-' + str(i) + '.pgn')

#read = []
#for i in range(5):
    #read.append(cv2.imread(image[i]))

# %%
images = [cv2.cvtColor(image, cv2.COLOR_BGR2RGB) for image in image]   
grid_display(image, titles, 5, (25,25))
plt.show()

# %%
cv2.addWeighted(image[0],0.7,image[1],0.3,0)
cv2.imshow('image', img) 
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-83a55f6d04e4> in <module>()
#       1 cv2.addWeighted(image[0],0.7,image[1],0.3,0)
# ----> 2 cv2.imshow('image', img)
#       3 cv2.waitKey(0)
#
# NameError: name 'img' is not defined

# %%
average similarities
calculate coefficients
